# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np


# %matplotlib inline

# %%
gourds = pd.read_csv('gourds.csv')
gourds.head(5)
# Out:
#    year type_id    weight  place                  grower_name            city  \
# 0  2013       F  154.5 lb    1.0  Ellenbecker, Todd & Sequoia         Gleason
# 1  2013       F  146.5 lb    2.0                  Razo, Steve  New Middletown
# 2  2013       F  145.0 lb    3.0  Ellenbecker, Todd & Sequoia         Glenson
# 3  2013       F  140.8 lb    4.0      Martin, Margaret & Glen  Combined Locks
# 4  2013       F  139.0 lb    5.5                 Barlow, John             NaN
#
#   state_prov        country                                     gpc_site  \
# 0  Wisconsin  United States                   Nekoosa Giant Pumpkin Fest
# 1       Ohio  United States  Ohio Valley Giant Pumpkin Growers Weigh-off
# 2  Wisconsin  United States                        Mishicot Pumpkin Fest
# 3  Wisconsin  United States          Cedarburg Wine and Harvest Festival
# 4  Wisconsin  United States                       Stillwater Harvestfest
#
#       seed_mother pollinator_father    ott  est_weight variety  weight_bk
# 0      209 Werner              Self  184.0       129.0     NaN      154.5
# 1    150.5 Snyder               NaN  194.0       151.0     NaN      146.5
# 2      209 Werner     103 Mackinnon  177.0       115.0     NaN      145.0
# 3  109 Martin '12    209 Werner '12  194.0       151.0     NaN      140.8
# 4  130.5 McKinnon              open    0.0         0.0     NaN      139.0

# %%
gourds.country.value_counts()
# Out:
# United States      17070
# Canada              4522
# Germany             2175
# Italy                846
# Austria              602
# France               405
# Belgium              360
# Japan                358
# United Kingdom       292
# The Netherlands      248
# Finland              244
# Spain                229
# Slovenia             167
# Switzerland          166
# Portugal             149
# New Zealand           77
# Poland                73
# Ireland               21
# Australia              5
# Unknown country        1
# Luxembourg             1
# Name: country, dtype: int64

# %%
gourds_chart = pd.DataFrame({'country':['United States', 'Canada', 'Germany', 'Italy', 'Austria'],
                       'count':[17070, 4522, 2175, 846, 602]})

ax = gourds_chart.plot.bar(x='country', y='count', rot=0)

# %% [markdown]
# 3.) United States shows up most frequently.

# %%
gourds['weight'] = gourds['weight'].str[:-3]

# %%
gourds = gourds.sort_values(['weight'], ascending=[False])

# %%
gourds['weight'] = pd.to_numeric(gourds['weight'])

# %%
updated_gourds = gourds.loc[gourds.groupby("year")["weight"].idxmax()]

# %%
updated_gourds
# Out:
#        year type_id  weight  place            grower_name  \
# 494    2013       P  2032.0    1.0          Mathison, Tim
# 3403   2014       P  2323.7    1.0            Meier, Beni
# 6599   2015       P  2230.5    1.0           Wallace, Ron
# 9964   2016       P  2624.6    1.0    Willemijns, Mathias
# 13114  2017       P  2363.0    1.0          Holland, Joel
# 16260  2018       P  2528.0    1.0          Geddes, Steve
# 19578  2019       P  2517.0    1.0  Haist, Karl & Beverly
# 22871  2020       P  2593.7    1.0    Paton, Ian & Stuart
# 25730  2021       P  2702.9    1.0       Cutrupi, Stefano
#
#                         city     state_prov         country  \
# 494                     Napa     California   United States
# 3403                 Pfungen          Other     Switzerland
# 6599                  Greene   Rhode Island   United States
# 9964                  Deurle  East Flanders         Belgium
# 13114                 Sumner     Washington   United States
# 16260               Boscawen  New Hampshire   United States
# 19578        Clarence Center       New York   United States
# 22871  Everton nr. Lymington        England  United Kingdom
# 25730       Radda in Chianti        Tuscany           Italy
#
#                                            gpc_site      seed_mother  \
# 494                          Uesugi Farms Weigh-off     2009 Wallace
# 3403            Europameisterschaft im Kurbiswiegen     2009 Wallace
# 6599                  SNGPG Frerichs Farm Weigh-off     2009 Wallace
# 9964            Europameisterschaft im Kurbiswiegen    2145 McMullen
# 13114  Safeway World Championship Pumpkin Weigh-Off  2145.5 McMullen
# 16260                                Deerfield Fair       1911 Urena
# 19578   Ohio Valley Giant Pumpkin Growers Weigh-off       2005 Haist
# 22871                   Royal Victoria Country Park   1875 MENDI "B"
# 25730                      Campionato dello Zuccone    1885.5 Werner
#
#       pollinator_father    ott  est_weight variety  weight_bk
# 494       1554 Mathison  475.0      2000.0     NaN     2032.0
# 3403     2328 Meier DMG  479.0      2035.0     NaN     2323.7
# 6599        1916 Barron  467.0      1929.0     NaN     2230.5
# 9964    1872 Willemijns  496.0      2175.0     NaN     2624.6
# 13114    2261.5 Wallace  473.0      2132.0     NaN     2363.0
# 16260     1803 Gadberry  490.0      2307.0     NaN     2528.0
# 19578              self  493.0      2332.0     NaN     2517.0
# 22871        2005 HAIST  502.0      2431.0     NaN     2593.7
# 25730              Self  514.0      2553.0     NaN     2702.9

# %% [markdown]
# 4.) Heaviest gourd is 2702lbs, from Tuscany, Italy.

# %%
y = [2032, 2324, 2231, 2625, 2363, 2528, 2517, 2594, 2703]
x = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
plt.plot(x, y)
plt.show()

# %% [markdown]
# 5.) Gourds are getting heavier through the years.

# %%
type_name = pd.read_csv('type_name.csv')
type_name
# Out:
#   type_id         type_name
# 0       F     Field Pumpkin
# 1       P     Giant Pumpkin
# 2       S      Giant Squash
# 3       W  Giant Watermelon
# 4       T            Tomato
# 5       L        Long Gourd

# %%
type_gourds = pd.merge(gourds, type_name, on='type_id', how='inner')
type_gourds.shape
# Out:
# (28011, 16)

# %%
type_gourds
# Out:
#        year type_id  weight  place           grower_name             city  \
# 0      2019       P  999.80  556.0     Verbraeken, alois      Rijkevorsel
# 1      2015       P  999.60  652.0          Brareu, Team  Niederdorfelden
# 2      2013       P  999.50  379.5          Leland, Neal            Canby
# 3      2013       P  999.50  379.5        Magarian, Marc        Goffstown
# 4      2015       P  999.50  653.0    Christensen, Brian          Rexburg
# ...     ...     ...     ...    ...                   ...              ...
# 28006  2021       T    0.28  369.0         Lambert, Tess       Barrington
# 28007  2018       T    0.25  365.0  Faust, Del and Julie      Fond Du Lac
# 28008  2016       T    0.24  326.0    D'entremont, Quinn         Glenwood
# 28009  2021       T    0.21  370.0          Ritter, Leif           Aurora
# 28010  2018       T    0.14  366.0       Lindley, Jeremy            Wynne
#
#           state_prov        country  \
# 0            Antwerp        Belgium
# 1              Other        Germany
# 2             Oregon  United States
# 3      New Hampshire  United States
# 4              Idaho  United States
# ...              ...            ...
# 28006  New Hampshire  United States
# 28007      Wisconsin  United States
# 28008    Nova Scotia         Canada
# 28009       Colorado  United States
# 28010       Arkansas  United States
#
#                                           gpc_site         seed_mother  \
# 0              Belgisch Kampioenschap pompoenwegen  1867,3Biermans2018
# 1              Europameisterschaft im Kurbiswiegen       2102 Meier 14
# 2             Baumans Farm Giant Pumpkin Weigh-off        1789 Wallace
# 3                                   Deerfield Fair        1381 Checkon
# 4                               Thanksgiving Point           1561 Reeb
# ...                                            ...                 ...
# 28006                               Deerfield Fair                 NaN
# 28007                        Mishicot Pumpkin Fest    7.0 VanderWielen
# 28008  The Great Howard Dill Giant Pumpkin Classic                 NaN
# 28009                               Early Tomatoes         9.44 La Rue
# 28010                            Operation Pumpkin                 NaN
#
#         pollinator_father    ott  est_weight  variety  weight_bk  \
# 0      1867,3Biermans2018  350.0       982.0      NaN     999.80
# 1                    self  366.0      1075.0      NaN     999.60
# 2            1041.5 McKie  356.0       994.0      NaN     999.50
# 3             1843 Geddes  370.0      1105.0      NaN     999.50
# 4        1003 Christensen  363.0      1049.0      NaN     999.50
# ...                   ...    ...         ...      ...        ...
# 28006                 NaN    NaN         NaN      NaN       0.28
# 28007                 NaN    NaN         NaN      NaN       0.25
# 28008                 NaN    NaN         NaN      NaN       0.24
# 28009                self    NaN         NaN  Domingo       0.21
# 28010                 NaN    NaN         NaN      NaN       0.14
#
#            type_name
# 0      Giant Pumpkin
# 1      Giant Pumpkin
# 2      Giant Pumpkin
# 3      Giant Pumpkin
# 4      Giant Pumpkin
# ...              ...
# 28006         Tomato
# 28007         Tomato
# 28008         Tomato
# 28009         Tomato
# 28010         Tomato
#
# [28011 rows x 16 columns]

# %%
type_gourds_byweight = type_gourds.groupby(['type_name']).mean()
type_gourds_byweight
# Out:
#                          year      weight       place         ott  est_weight  \
# type_name
# Field Pumpkin     2016.876229   79.456309  154.293775   58.461230   37.345832
# Giant Pumpkin     2016.886438  776.033885  893.706568  266.681812  695.968413
# Giant Squash      2016.935599  527.298348   95.251640  205.439475  431.540847
# Giant Watermelon  2016.987689  127.149110  140.855838  103.721207   96.137014
# Long Gourd        2017.061350   94.567945  110.448875    5.306237    0.581800
# Tomato            2017.286665    3.176921  179.193538         NaN         NaN
#
#                    weight_bk
# type_name
# Field Pumpkin      79.456309
# Giant Pumpkin     776.033885
# Giant Squash      527.298348
# Giant Watermelon  127.149110
# Long Gourd         94.567945
# Tomato              3.176921

# %% [markdown]
# 6.) Giant pumpkins are heaviest on average.

# %%
gourds_chart = pd.DataFrame({'type_name':['Tomato', 'Field Pumpkin', 'Long Gourd', 'Giant Watermelon', 'Giant Squash', 'Giant Pumpkin'],
                       'avg_weight':[3.18, 79.5, 94.6, 127, 527, 776]})

ax = gourds_chart.plot.barh(x='type_name', y='avg_weight', rot=0)

# %%
type_gourds['weight_error'] = type_gourds['weight'] - type_gourds['est_weight']
error_gourds = type_gourds.sort_values(['weight_error'], ascending=[False])
error_gourds = error_gourds[error_gourds['est_weight'] != 0.0]

# %%
error_gourds = error_gourds[error_gourds['weight_error'].notna()]
error_gourds.tail(1)
# Out:
#       year type_id  weight   place     grower_name       city state_prov  \
# 8320  2019       P   316.0  1403.0  Shenfish, Gary  Littleton   Colorado
#
#             country                        gpc_site   seed_mother  \
# 8320  United States  Fort Collins Nursery Weigh-off  2170 Daletes
#
#      pollinator_father     ott  est_weight variety  weight_bk      type_name  \
# 8320        1911 Urena  1132.0     11033.0     NaN      316.0  Giant Pumpkin
#
#       weight_error
# 8320      -10717.0

# %% [markdown]
# 7.) Worst over-estimation is the one above. It was an estimated weight of 11,000lbs when the actual weight was 316lbs.

# %%
error_gourds
# Out:
#        year type_id  weight   place           grower_name             city  \
# 12818  2014       P  1339.4   236.0          Sundin, Eric     Stoney Creek
# 11509  2016       P  1536.5   151.0        Tessier, David  N-D Mont-Carmel
# 719    2015       P   930.0   745.0            Team Grams         Fox Lake
# 1534   2018       P   859.0   772.5          Jarvis, Joel        St.Thomas
# 1357   2018       P   874.5   754.0          Court, Tamri       Port Elgin
# ...     ...     ...     ...     ...                   ...              ...
# 2186   2014       P   803.0   800.0         Powell, Jesse      Oil Springs
# 16225  2017       S   732.0    56.5        Sikorski, John           Suring
# 19388  2016       W   160.5    94.0      Thompson, Travis         Florence
# 12248  2017       P  1419.8   231.0  Wuersching, Matthias        Einhausen
# 8320   2019       P   316.0  1403.0        Shenfish, Gary        Littleton
#
#       state_prov        country                         gpc_site  \
# 12818    Ontario         Canada           Port Elgin Pumpkinfest
# 11509     Quebec         Canada           Port Elgin Pumpkinfest
# 719    Wisconsin  United States       Nekoosa Giant Pumpkin Fest
# 1534     Ontario         Canada           Port Elgin Pumpkinfest
# 1357     Ontario         Canada  Port Elgin Pumpkinfest (Sunday)
# ...          ...            ...                              ...
# 2186     Ontario         Canada           Port Elgin Pumpkinfest
# 16225  Wisconsin  United States            Mishicot Pumpkin Fest
# 19388    Ontario         Canada  Port Elgin Pumpkinfest (Sunday)
# 12248      Hesse        Germany      Early Weigh-off Ludwigsburg
# 8320    Colorado  United States   Fort Collins Nursery Weigh-off
#
#              seed_mother pollinator_father     ott  est_weight variety  \
# 12818         702 Sundin       1442 Metesa   194.0       170.0     NaN
# 11509        1965 Brandt              Self   262.0       404.0     NaN
# 719    1037 Bird-Gantner               NaN   190.0       161.0     NaN
# 1534          150 Butler        1803 Houle   158.0        96.0     NaN
# 1357           154 Lyons              self   181.0       140.0     NaN
# ...                  ...               ...     ...         ...     ...
# 2186          411 Powell        411 Powell   517.0      2336.0     NaN
# 16225        1196 Martin            selfed   496.0      2369.0     NaN
# 19388       193 Mitchell      193 Mitchell     0.0      1887.0     NaN
# 12248        1781 Zywiec       900 Gansert  1072.0      9819.0     NaN
# 8320        2170 Daletes        1911 Urena  1132.0     11033.0     NaN
#
#        weight_bk         type_name  weight_error
# 12818     1339.4     Giant Pumpkin        1169.4
# 11509     1536.5     Giant Pumpkin        1132.5
# 719        930.0     Giant Pumpkin         769.0
# 1534       859.0     Giant Pumpkin         763.0
# 1357       874.5     Giant Pumpkin         734.5
# ...          ...               ...           ...
# 2186       803.0     Giant Pumpkin       -1533.0
# 16225      732.0      Giant Squash       -1637.0
# 19388      160.5  Giant Watermelon       -1726.5
# 12248     1419.8     Giant Pumpkin       -8399.2
# 8320       316.0     Giant Pumpkin      -10717.0
#
# [17059 rows x 17 columns]

# %%
print(error_gourds[(error_gourds[['weight_error']]<0).all(axis=1)])
# Out:
#        year type_id  weight   place                  grower_name         city  \
# 20127  2016       W   100.9   181.0  Bartoli, Roberto e Federico          NaN
# 18373  2016       W     4.9   291.0               Brumaghim, Tim   Cobleskill
# 23716  2020       F    48.9   186.0                Kobel, Stefan     Elmstein
# 6128   2015       P   489.9  1374.0            Martini, Guenther       Merzig
# 728    2014       P   929.9   641.0                 Mendi, Ruben    Valtierra
# ...     ...     ...     ...     ...                          ...          ...
# 2186   2014       P   803.0   800.0                Powell, Jesse  Oil Springs
# 16225  2017       S   732.0    56.5               Sikorski, John       Suring
# 19388  2016       W   160.5    94.0             Thompson, Travis     Florence
# 12248  2017       P  1419.8   231.0         Wuersching, Matthias    Einhausen
# 8320   2019       P   316.0  1403.0               Shenfish, Gary    Littleton
#
#                  state_prov        country  \
# 20127        Emilia-Romagna          Italy
# 18373              New York  United States
# 23716  Rhineland-Palatinate        Germany
# 6128                  Other        Germany
# 728                 Navarre          Spain
# ...                     ...            ...
# 2186                Ontario         Canada
# 16225             Wisconsin  United States
# 19388               Ontario         Canada
# 12248                 Hesse        Germany
# 8320               Colorado  United States
#
#                                                 gpc_site       seed_mother  \
# 20127                           Miss Anguria a Novellara  306 Bartoli 2013
# 18373                        Saratoga Giant Pumpkin Fest            Barber
# 23716  Offene Rheinland-Pfalzische Kurbiswiegemeister...       68.8 Andres
# 6128                          Gartenbauschule Langenlois       411 Martini
# 728             Concurso Calabazas Gigantes de Valtierra      Urena 1401lb
# ...                                                  ...               ...
# 2186                              Port Elgin Pumpkinfest        411 Powell
# 16225                              Mishicot Pumpkin Fest       1196 Martin
# 19388                    Port Elgin Pumpkinfest (Sunday)      193 Mitchell
# 12248                        Early Weigh-off Ludwigsburg       1781 Zywiec
# 8320                      Fort Collins Nursery Weigh-off      2170 Daletes
#
#       pollinator_father     ott  est_weight variety  weight_bk  \
# 20127              open   151.0       101.0     NaN      100.9
# 18373              Open    54.0         5.0     NaN        4.9
# 23716              self   134.0        49.0     NaN       48.9
# 6128        365 Martini   280.0       490.0     NaN      489.9
# 728       Urena 1401 lb   348.0       930.0     NaN      929.9
# ...                 ...     ...         ...     ...        ...
# 2186         411 Powell   517.0      2336.0     NaN      803.0
# 16225            selfed   496.0      2369.0     NaN      732.0
# 19388      193 Mitchell     0.0      1887.0     NaN      160.5
# 12248       900 Gansert  1072.0      9819.0     NaN     1419.8
# 8320         1911 Urena  1132.0     11033.0     NaN      316.0
#
#               type_name  weight_error
# 20127  Giant Watermelon          -0.1
# 18373  Giant Watermelon          -0.1
# 23716     Field Pumpkin          -0.1
# 6128      Giant Pumpkin          -0.1
# 728       Giant Pumpkin          -0.1
# ...                 ...           ...
# 2186      Giant Pumpkin       -1533.0
# 16225      Giant Squash       -1637.0
# 19388  Giant Watermelon       -1726.5
# 12248     Giant Pumpkin       -8399.2
# 8320      Giant Pumpkin      -10717.0
#
# [8421 rows x 17 columns]

# %%
(8421/17059)*100
# Out:
# 49.36397209684038

# %% [markdown]
# 7b.) About 49% of estimated weights are over-estimations.

# %%
type_gourds[['weight', 'est_weight']].corr()
# Out:
#               weight  est_weight
# weight      1.000000    0.907881
# est_weight  0.907881    1.000000

# %%
type_gourds.plot(kind = 'scatter',
             x = 'est_weight',
             y = 'weight',
             figsize = (7,5));

# %% [markdown]
# 8.) There is quite a positive correlation when it comes to comparing estimated weight with actual weight, meaning estimations are fairly accurate. I did also notice that people tended to underestimate a gourd's size, for all types.

# %%
winning_gourds =  type_gourds[type_gourds['place'] < 11]

# %%
winning_gourds
# Out:
#        year type_id   weight  place              grower_name  \
# 8929   2021       P  2702.90    1.0         Cutrupi, Stefano
# 9035   2016       P  2624.60    1.0      Willemijns, Mathias
# 9084   2020       P  2593.70    1.0      Paton, Ian & Stuart
# 9124   2020       P  2551.90    2.0             Mendi, Ruben
# 9152   2018       P  2528.00    1.0            Geddes, Steve
# ...     ...     ...      ...    ...                      ...
# 25076  2013       T     5.33    7.0  Martin, Margaret & Glen
# 25103  2013       T     5.22    8.0        Hunt, Phil & Jane
# 25113  2013       T     5.20    9.0             Chris, Lyons
# 25130  2013       T     5.14   10.0         Montgomery, Greg
# 27330  2020       T    10.80    1.0          Sutherland, Dan
#
#                         city     state_prov         country  \
# 8929        Radda in Chianti        Tuscany           Italy
# 9035                  Deurle  East Flanders         Belgium
# 9084   Everton nr. Lymington        England  United Kingdom
# 9124               VALTIERRA        Navarre           Spain
# 9152                Boscawen  New Hampshire   United States
# ...                      ...            ...             ...
# 25076         Combined Locks      Wisconsin   United States
# 25103                Cameron        Ontario          Canada
# 25113            Scarborough        Ontario          Canada
# 25130           Port Carling        Ontario          Canada
# 27330            Walla Walla     Washington   United States
#
#                                        gpc_site          seed_mother  \
# 8929                   Campionato dello Zuccone        1885.5 Werner
# 9035        Europameisterschaft im Kurbiswiegen        2145 McMullen
# 9084                Royal Victoria Country Park       1875 MENDI "B"
# 9124   Concurso Calabazas Gigantes de Valtierra    2183.7 Mendi 2019
# 9152                             Deerfield Fair           1911 Urena
# ...                                         ...                  ...
# 25076                            Early Tomatoes       4.79 Martin 11
# 25103                            Early Tomatoes  5.5 Johnson/ Butler
# 25113                            Early Tomatoes   5.5 Johnson/Butler
# 25130                            Early Tomatoes          4.29 Boudyo
# 27330                            Early Tomatoes      9.44 Sutherland
#
#       pollinator_father    ott  est_weight  variety  weight_bk      type_name  \
# 8929               Self  514.0      2553.0      NaN    2702.90  Giant Pumpkin
# 9035    1872 Willemijns  496.0      2175.0      NaN    2624.60  Giant Pumpkin
# 9084         2005 HAIST  502.0      2431.0      NaN    2593.70  Giant Pumpkin
# 9124               self  485.0      2255.0      NaN    2551.90  Giant Pumpkin
# 9152      1803 Gadberry  490.0      2307.0      NaN    2528.00  Giant Pumpkin
# ...                 ...    ...         ...      ...        ...            ...
# 25076              open    NaN         NaN      NaN       5.33         Tomato
# 25103              Open    NaN         NaN      NaN       5.22         Tomato
# 25113              self    NaN         NaN      NaN       5.20         Tomato
# 25130               NaN    NaN         NaN      NaN       5.14         Tomato
# 27330               NaN    NaN         NaN  Domingo      10.80         Tomato
#
#        weight_error
# 8929          149.9
# 9035          449.6
# 9084          162.7
# 9124          296.9
# 9152          221.0
# ...             ...
# 25076           NaN
# 25103           NaN
# 25113           NaN
# 25130           NaN
# 27330           NaN
#
# [541 rows x 17 columns]

# %%
growers_gourd = winning_gourds.groupby(['grower_name', 'type_id']).agg({'place': ['count']})
growers_gourd.columns = ['type_count']
growers_gourd = growers_gourd.reset_index()
print(growers_gourd)
# Out:
#                grower_name type_id  type_count
# 0              Alan, Eaton       L           2
# 1        Ansems, Catharina       L           2
# 2            Ansems, Frank       L           4
# 3             Ansems, Fred       L           4
# 4             Ansems, Fred       S           1
# ..                     ...     ...         ...
# 279  Zappa, Lee and Derrik       S           1
# 280        Zywiec, Lorelee       P           1
# 281            kent, Chris       W           5
# 282       team, Willemijns       P           1
# 283           vial, Andrew       W           2
#
# [284 rows x 3 columns]

# %%
growers_gourd['grower_name'].mode()
# Out:
# 0    Martin, Margaret & Glen
# Name: grower_name, dtype: object

# %%
theglens = winning_gourds.loc[winning_gourds['grower_name'] == 'Martin, Margaret & Glen']
theglens
# Out:
#        year type_id   weight  place              grower_name            city  \
# 17478  2016       S  1196.00    8.0  Martin, Margaret & Glen  Combined Locks
# 17546  2014       S  1103.60   10.0  Martin, Margaret & Glen  Combined Locks
# 21313  2014       L   130.38    5.0  Martin, Margaret & Glen  Combined Locks
# 24242  2013       F   140.80    4.0  Martin, Margaret & Glen  Combined Locks
# 24878  2014       T     7.45    2.0  Martin, Margaret & Glen  Combined Locks
# 25076  2013       T     5.33    7.0  Martin, Margaret & Glen  Combined Locks
#
#       state_prov        country                             gpc_site  \
# 17478  Wisconsin  United States           Nekoosa Giant Pumpkin Fest
# 17546  Wisconsin  United States  Cedarburg Wine and Harvest Festival
# 21313  Wisconsin  United States  Cedarburg Wine and Harvest Festival
# 24242  Wisconsin  United States  Cedarburg Wine and Harvest Festival
# 24878  Wisconsin  United States  Cedarburg Wine and Harvest Festival
# 25076  Wisconsin  United States                       Early Tomatoes
#
#                          seed_mother  pollinator_father    ott  est_weight  \
# 17478                    1262 Jutras      1094.6 Butler  381.0      1191.0
# 17546              1023.5 Martin '13  1264 Pierpont '13  363.0      1045.0
# 21313              121.25 Martin '13  137.75 Wright '12    0.0         0.0
# 24242                 109 Martin '12     209 Werner '12  194.0       151.0
# 24878  5.63 Martin uof '13 (big zac)               open    NaN         NaN
# 25076                 4.79 Martin 11               open    NaN         NaN
#
#        variety  weight_bk      type_name  weight_error
# 17478      NaN    1196.00   Giant Squash          5.00
# 17546      NaN    1103.60   Giant Squash         58.60
# 21313      NaN     130.38     Long Gourd        130.38
# 24242      NaN     140.80  Field Pumpkin        -10.20
# 24878  Big Zac       7.45         Tomato           NaN
# 25076      NaN       5.33         Tomato           NaN

# %% [markdown]
# 9.) Margaret & Glen Martin have top 10 finishes among the most categories (5). Their best finish is 2nd, with a seven and a half pound tomato. (impressive)
# Answered this question by finding the mode in the grower_name column, then made a dataframe with those particular strings in the name column. This led me to find all the top 10s that the Glens grew.

# %%
mother_count = type_gourds.seed_mother.value_counts()

# %%
father_count = type_gourds.pollinator_father.value_counts()

# %% [markdown]
# two known gourds appeared to have been the mother seed at least 100 times, with most of the mother plants being "unknown". As for pollinators/"fathers", there seems to be at least four known pollinators that have reached at least 100 offspring. There is also "open", "self", and "unknown" that have reached 100 offspring.

# %%
question10c = type_gourds[['year', 'type_name', 'gpc_site', 'seed_mother', 'pollinator_father']].copy()
question10c
# Out:
#        year      type_name                                     gpc_site  \
# 0      2019  Giant Pumpkin          Belgisch Kampioenschap pompoenwegen
# 1      2015  Giant Pumpkin          Europameisterschaft im Kurbiswiegen
# 2      2013  Giant Pumpkin         Baumans Farm Giant Pumpkin Weigh-off
# 3      2013  Giant Pumpkin                               Deerfield Fair
# 4      2015  Giant Pumpkin                           Thanksgiving Point
# ...     ...            ...                                          ...
# 28006  2021         Tomato                               Deerfield Fair
# 28007  2018         Tomato                        Mishicot Pumpkin Fest
# 28008  2016         Tomato  The Great Howard Dill Giant Pumpkin Classic
# 28009  2021         Tomato                               Early Tomatoes
# 28010  2018         Tomato                            Operation Pumpkin
#
#               seed_mother   pollinator_father
# 0      1867,3Biermans2018  1867,3Biermans2018
# 1           2102 Meier 14                self
# 2            1789 Wallace        1041.5 McKie
# 3            1381 Checkon         1843 Geddes
# 4               1561 Reeb    1003 Christensen
# ...                   ...                 ...
# 28006                 NaN                 NaN
# 28007    7.0 VanderWielen                 NaN
# 28008                 NaN                 NaN
# 28009         9.44 La Rue                self
# 28010                 NaN                 NaN
#
# [28011 rows x 5 columns]

# %%
question10c["parents"] = question10c["seed_mother"] + question10c["pollinator_father"]
question10c = question10c[question10c['parents'].notna()]
question10c
# Out:
#        year      type_name                              gpc_site  \
# 0      2019  Giant Pumpkin   Belgisch Kampioenschap pompoenwegen
# 1      2015  Giant Pumpkin   Europameisterschaft im Kurbiswiegen
# 2      2013  Giant Pumpkin  Baumans Farm Giant Pumpkin Weigh-off
# 3      2013  Giant Pumpkin                        Deerfield Fair
# 4      2015  Giant Pumpkin                    Thanksgiving Point
# ...     ...            ...                                   ...
# 27996  2014         Tomato                 Country Farm and Feed
# 27998  2021         Tomato         Nicks Garden Center Weigh-off
# 28001  2020         Tomato         Nicks Garden Center Weigh-off
# 28005  2020         Tomato   Smith Farms Giant Pumpkin Weigh-off
# 28009  2021         Tomato                        Early Tomatoes
#
#               seed_mother   pollinator_father  \
# 0      1867,3Biermans2018  1867,3Biermans2018
# 1           2102 Meier 14                self
# 2            1789 Wallace        1041.5 McKie
# 3            1381 Checkon         1843 Geddes
# 4               1561 Reeb    1003 Christensen
# ...                   ...                 ...
# 27996         3.6 english                open
# 27998       4.28 SPAZIANI                SELF
# 28001          5.59 Zappa                self
# 28005       VANDER WIELEN                SELF
# 28009         9.44 La Rue                self
#
#                                     parents
# 0      1867,3Biermans20181867,3Biermans2018
# 1                         2102 Meier 14self
# 2                  1789 Wallace1041.5 McKie
# 3                   1381 Checkon1843 Geddes
# 4                 1561 Reeb1003 Christensen
# ...                                     ...
# 27996                       3.6 englishopen
# 27998                     4.28 SPAZIANISELF
# 28001                        5.59 Zappaself
# 28005                     VANDER WIELENSELF
# 28009                       9.44 La Rueself
#
# [17603 rows x 6 columns]

# %%
parent_count = question10c['parents'].value_counts()
parent_count.head(25)
# Out:
# unknownopen                       127
# unknownunknown                     90
# UnknownUnknown                     80
# UnknownOpen                        65
# OpenOpen                           23
# Unknownopen                        23
# openopen                           22
# 306 Bartoli 2013open               13
# 207.2 '19 Bartoli Gabrieleopen     13
# 81 Wolfopen                        13
# 2145 McMullenself                  13
# 81 Wolfself                        13
# 293 Bartoli Gabrieleopen           13
# 302 KentSelf                       12
# 1911 UrenaSelf                     12
# 316 Edwardsopen                    12
# 1495 Stelts2009 Wallace            12
# 4.28 SpazianiOpen                  11
# 305 MuddSelf                       10
# 7.10 FossOpen                      10
# 140 Crewsself                      10
# 6.66 Spazianiopen                  10
# Dillopen                           10
# 2005 HaistSelf                     10
# 245 BartoliOpen                    10
# Name: parents, dtype: int64

# %% [markdown]
# 10c.) It seems as though no known/named parent combination accounted for at least 100 offspring that has been weighed.
